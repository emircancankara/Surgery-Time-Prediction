# %%
import pandas as pd
df=pd.read_csv('train.csv', encoding='latin-1')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df.head()
# Out:
#      ID      DiagnosticICD10Code              SurgeryGroup   AnesthesiaType  \
# 0  1829                  {'L05'}                     {'C'}  Spinal Anestezi
# 1  1104                {'N20.1'}                     {'C'}  Spinal Anestezi
# 2  1850                {'K80.8'}                     {'B'}   Genel Anestezi
# 3  1059           {nan, 'M51.1'}                  {0, 'B'}   Genel Anestezi
# 4   608  {'M51.1', nan, 'M48.0'}  {0, 'B', 'C', 'D', 'A3'}   Genel Anestezi
#
#                                          SurgeryName  Age     Sex  \
# 0                                     Pilonidal kist   26    MALE
# 1                                                NaN   24    MALE
# 2                                Kolelitiazis, di?er   38    MALE
# 3  Lumbar ve di?er intervertebral disk bozuklukla...   41  FEMALE
# 4  Lumbar ve di?er intervertebral disk bozuklukla...   49  FEMALE
#
#                  Service  DoctorID  AnaesthetistID  ElapsedTime(second)
# ...

# %%
df.shape
# Out:
# (2822, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2822 entries, 0 to 2821
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2822 non-null   int64
#  1   DiagnosticICD10Code  2601 non-null   object
#  2   SurgeryGroup         2822 non-null   object
#  3   AnesthesiaType       2601 non-null   object
#  4   SurgeryName          2447 non-null   object
#  5   Age                  2822 non-null   int64
#  6   Sex                  2822 non-null   object
#  7   Service              2822 non-null   object
#  8   DoctorID             2822 non-null   int64
#  9   AnaesthetistID       2822 non-null   int64
#  10  ElapsedTime(second)  2822 non-null   int64
# dtypes: int64(5), object(6)
# memory usage: 242.6+ KB

# %%
# Categorical Features: DiagnosticICD10Code, SurgeryGroup, AnesthesiaType, SurgeryName, Sex, Service, DoctorID, AnaesthetistID
df.isnull().sum()
# Out:
# ID                       0
# DiagnosticICD10Code    221
# SurgeryGroup             0
# AnesthesiaType         221
# SurgeryName            375
# Age                      0
# Sex                      0
# Service                  0
# DoctorID                 0
# AnaesthetistID           0
# ElapsedTime(second)      0
# dtype: int64

# %%
df= df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# ID                     0
# DiagnosticICD10Code    0
# SurgeryGroup           0
# AnesthesiaType         0
# SurgeryName            0
# Age                    0
# Sex                    0
# Service                0
# DoctorID               0
# AnaesthetistID         0
# ElapsedTime(second)    0
# dtype: int64

# %%
df.shape
# Out:
# (2264, 11)

# %%
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Certain infectious and parasitic diseases' if "'A" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Certain infectious and parasitic diseases' if "'B" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Neoplasms' if "'C" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Neoplasms' if "'D0"in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Neoplasms' if "'D1"in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Neoplasms' if "'D2"in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Neoplasms' if "'D3"in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Neoplasms' if "'D4"in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism' if "'D5" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism' if "'D6" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism' if "'D7" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism' if "'D8" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism' if "'D9" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Endocrine, nutritional and metabolic diseases' if "'E" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Mental, Behavioral and Neurodevelopmental disorders' if "'F" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the nervous system' if "'G" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the eye and adnexa' if "'H0" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the eye and adnexa' if "'H1" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the eye and adnexa' if "'H2" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the eye and adnexa' if "'H3" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the eye and adnexa' if "'H4" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the eye and adnexa' if "'H5" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the ear and mastoid process' if "'H6" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the ear and mastoid process' if "'H7" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the ear and mastoid process' if "'H8" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the ear and mastoid process' if "'H9" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the circulatory systems' if "'I" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the respiratory system' if "'J" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the digestive system' if "'K" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the skin and subcutaneous tissue' if "'L" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the musculoskeletal system and connective tissue' if "'M" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the genitourinary system' if "'N" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Pregnancy, childbirth and the puerperium' if "'O" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Certain conditions originating in the perinatal period' if "'P" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Congenital malformations, deformations and chromosomal abnormalities' if "'Q" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified' if "'R" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Injury, poisoning and certain other consequences of external causes' if "'S" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Injury, poisoning and certain other consequences of external causes' if "'T" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Codes for special purposes' if "'U" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'External causes of morbidity' if "'V" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'External causes of morbidity' if "'W" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'External causes of morbidity' if "'Y" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Factors influencing health status and contact with health services' if "'Z" in x else x)

# %%
df.head()
# Out:
#      ID                                DiagnosticICD10Code  \
# 0  1829       Diseases of the skin and subcutaneous tissue
# 2  1850                   Diseases of the digestive system
# 3  1059  Diseases of the musculoskeletal system and con...
# 4   608  Diseases of the musculoskeletal system and con...
# 5  1895  Diseases of the musculoskeletal system and con...
#
#                SurgeryGroup   AnesthesiaType  \
# 0                     {'C'}  Spinal Anestezi
# 2                     {'B'}   Genel Anestezi
# 3                  {0, 'B'}   Genel Anestezi
# 4  {0, 'B', 'C', 'D', 'A3'}   Genel Anestezi
# 5                {'D', 'C'}   Genel Anestezi
#
#                                          SurgeryName  Age     Sex  \
# 0                                     Pilonidal kist   26    MALE
# 2                                Kolelitiazis, di?er   38    MALE
# 3  Lumbar ve di?er intervertebral disk bozuklukla...   41  FEMALE
# ...

# %%
df["DiagnosticICD10Code"].value_counts()
# Out:
# Diseases of the digestive system                                                                       726
# Diseases of the circulatory systems                                                                    497
# Diseases of the musculoskeletal system and connective tissue                                           336
# Diseases of the genitourinary system                                                                   212
# Diseases of the skin and subcutaneous tissue                                                           136
# Diseases of the eye and adnexa                                                                          92
# Diseases of the respiratory system                                                                      89
# Injury, poisoning and certain other consequences of external causes                                     48
# Factors influencing health status and contact with health services                                      44
# ...

# %%
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "4000" if "A1" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "2500" if "A2" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "1250" if "A3" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "750" if "B" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "400" if "C" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "200" if "D" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "100" if "E" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "0" if "{0}" in x else x)

# %%
df.head()
# Out:
#      ID                                DiagnosticICD10Code SurgeryGroup  \
# 0  1829       Diseases of the skin and subcutaneous tissue          400
# 2  1850                   Diseases of the digestive system          750
# 3  1059  Diseases of the musculoskeletal system and con...          750
# 4   608  Diseases of the musculoskeletal system and con...         1250
# 5  1895  Diseases of the musculoskeletal system and con...          400
#
#     AnesthesiaType                                        SurgeryName  Age  \
# 0  Spinal Anestezi                                     Pilonidal kist   26
# 2   Genel Anestezi                                Kolelitiazis, di?er   38
# 3   Genel Anestezi  Lumbar ve di?er intervertebral disk bozuklukla...   41
# 4   Genel Anestezi  Lumbar ve di?er intervertebral disk bozuklukla...   49
# 5   Genel Anestezi                      Burnun kazan?lm?? deformitesi   33
#
#       Sex                Service  DoctorID  AnaesthetistID  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2264 entries, 0 to 2600
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2264 non-null   int64
#  1   DiagnosticICD10Code  2264 non-null   object
#  2   SurgeryGroup         2264 non-null   object
#  3   AnesthesiaType       2264 non-null   object
#  4   SurgeryName          2264 non-null   object
#  5   Age                  2264 non-null   int64
#  6   Sex                  2264 non-null   object
#  7   Service              2264 non-null   object
#  8   DoctorID             2264 non-null   int64
#  9   AnaesthetistID       2264 non-null   int64
#  10  ElapsedTime(second)  2264 non-null   int64
# dtypes: int64(5), object(6)
# memory usage: 212.2+ KB

# %%
df["SurgeryGroup"]=df["SurgeryGroup"].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2264 entries, 0 to 2600
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2264 non-null   int64
#  1   DiagnosticICD10Code  2264 non-null   object
#  2   SurgeryGroup         2264 non-null   int64
#  3   AnesthesiaType       2264 non-null   object
#  4   SurgeryName          2264 non-null   object
#  5   Age                  2264 non-null   int64
#  6   Sex                  2264 non-null   object
#  7   Service              2264 non-null   object
#  8   DoctorID             2264 non-null   int64
#  9   AnaesthetistID       2264 non-null   int64
#  10  ElapsedTime(second)  2264 non-null   int64
# dtypes: int64(6), object(5)
# memory usage: 212.2+ KB

# %%
df["Sex"].value_counts()
# Out:
# MALE      1224
# FEMALE    1040
# Name: Sex, dtype: int64

# %%
df["SurgeryGroup"].value_counts()
# Out:
# 750     834
# 400     688
# 100     441
# 1250    136
# 200     118
# 0        45
# 2500      2
# Name: SurgeryGroup, dtype: int64

# %%
df["AnesthesiaType"].value_counts()
# Out:
# Genel Anestezi                         921
# Sedo Analjezi                          708
# Spinal Anestezi                        553
# Lokal Anestezi                          52
# Rejyonel Sinir Blo?u                    14
# Epidural ve Genel Anestezi               8
# Epidural Anestezi                        2
# Periferik Bloklar                        2
# Spinal ve Genel Anestezi                 2
# Seçilmemi?                               1
# Periferik Bloklar ve Genel Anestezi      1
# Name: AnesthesiaType, dtype: int64

# %%
df["SurgeryName"].value_counts()
# Out:
# Ülser veya enflamasyon olmadan alt ekstremitenin variköz venleri           370
# Bilateral inguinal herni, obstrüksiyonsuz veya gangrensiz                  223
# Kolelitiazis, di?er                                                        204
# Lumbar ve di?er intervertebral disk bozukluklar?, radikülopati ile         106
# Pilonidal kist                                                              78
#                                                                           ...
# Variköz venler, di?er yerlerin                                               1
# Ulna ?aft? k?r???                                                            1
# Ventral herni, gangrenli                                                     1
# Ulnar sinir lezyonu                                                          1
# Kabul edilebilir olmayan kozmetik görünüm için di?er plastik cerrahiler      1
# Name: SurgeryName, Length: 230, dtype: int64

# %%
df["Service"].value_counts()
# Out:
# GENEL CERRAH? SERV?S?          833
# KVC SERV?S?                    411
# ORTOPED? SERV?S?               330
# ÜROLOJ? SERV?S?                266
# PLAST?K CERRAH?                109
# KBB SERV?S?                     88
# NÖRO??RÜRJ? SERV?S?             81
# GÖZ HASTALIKLARI SERV?S?        78
# KADIN DO?UM SERV?S?             38
# GENEL KARMA CERRAH? SERV?S?     30
# Name: Service, dtype: int64

# %%
df["DoctorID"].value_counts()
# Out:
# 36    217
# 5     208
# 25    201
# 46    170
# 47    165
# 42    127
# 43    124
# 39     90
# 31     86
# 49     74
# 21     71
# 8      71
# 40     58
# 29     57
# 26     54
# 15     50
# 32     48
# 33     48
# 23     39
# 11     39
# 27     37
# 48     30
# 10     29
# 6      28
# 18     23
# 17     22
# 28     19
# 22     11
# 35     10
# 45     10
# 19      8
# 16      8
# 37      7
# 20      6
# 2       3
# 41      3
# 9       3
# 4       2
# 12      2
# 44      2
# 24      1
# 1       1
# 7       1
# 14      1
# Name: DoctorID, dtype: int64

# %%
df["AnaesthetistID"].value_counts()
# Out:
# 12    333
# 4     325
# 2     272
# 6     256
# 13    255
# 11    243
# 14    216
# 9      88
# 10     69
# 3      62
# 1      49
# 7      34
# 15     28
# 5      25
# 16      9
# Name: AnaesthetistID, dtype: int64

# %%
df.head()
# Out:
#      ID                                DiagnosticICD10Code  SurgeryGroup  \
# 0  1829       Diseases of the skin and subcutaneous tissue           400
# 2  1850                   Diseases of the digestive system           750
# 3  1059  Diseases of the musculoskeletal system and con...           750
# 4   608  Diseases of the musculoskeletal system and con...          1250
# 5  1895  Diseases of the musculoskeletal system and con...           400
#
#     AnesthesiaType                                        SurgeryName  Age  \
# 0  Spinal Anestezi                                     Pilonidal kist   26
# 2   Genel Anestezi                                Kolelitiazis, di?er   38
# 3   Genel Anestezi  Lumbar ve di?er intervertebral disk bozuklukla...   41
# 4   Genel Anestezi  Lumbar ve di?er intervertebral disk bozuklukla...   49
# 5   Genel Anestezi                      Burnun kazan?lm?? deformitesi   33
#
#       Sex                Service  DoctorID  AnaesthetistID  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
df["DiagnosticICD10Code"]=encoder.fit_transform(df["DiagnosticICD10Code"])
df["AnesthesiaType"]=encoder.fit_transform(df["AnesthesiaType"])
df["Sex"]=encoder.fit_transform(df["Sex"])
df["Service"]=encoder.fit_transform(df["Service"])
df["DoctorID"]=encoder.fit_transform(df["DoctorID"])
df["AnaesthetistID"]=encoder.fit_transform(df["AnaesthetistID"])

# %%
df.head()
# Out:
#      ID  DiagnosticICD10Code  SurgeryGroup  AnesthesiaType  \
# 0  1829                   11           400               9
# 2  1850                    4           750               2
# 3  1059                    8           750               2
# 4   608                    8          1250               2
# 5  1895                    8           400               2
#
#                                          SurgeryName  Age  Sex  Service  \
# 0                                     Pilonidal kist   26    1        0
# 2                                Kolelitiazis, di?er   38    1        0
# 3  Lumbar ve di?er intervertebral disk bozuklukla...   41    0        7
# 4  Lumbar ve di?er intervertebral disk bozuklukla...   49    0        7
# 5                      Burnun kazan?lm?? deformitesi   33    1        8
#
#    DoctorID  AnaesthetistID  ElapsedTime(second)
# 0         3              11                 6333
# 2        31              12                 4647
# ...

# %%
x=df.drop(columns=["ID", "ElapsedTime(second)","SurgeryName"], axis=1)
y=df["ElapsedTime(second)"]

# %%
x.head()
# Out:
#    DiagnosticICD10Code  SurgeryGroup  AnesthesiaType  Age  Sex  Service  \
# 0                   11           400               9   26    1        0
# 2                    4           750               2   38    1        0
# 3                    8           750               2   41    0        7
# 4                    8          1250               2   49    0        7
# 5                    8           400               2   33    1        8
#
#    DoctorID  AnaesthetistID
# 0         3              11
# 2        31              12
# 3        36               5
# 4        36               7
# 5        33              11

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2, random_state=2)

# %%
reg=LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([2594.44060679, 3141.73741606, 4781.23621305, 4601.31650409,
#        2678.69373531, 5634.91861433, 4445.14367752, 5589.97956991,
#        2332.1243979 , 4159.45370242, 6068.44796806, 4039.26473829,
#        4037.59050117, 2878.93108927, 6236.20716631, 2551.06858835,
#        5221.37086276, 4796.82048903, 5773.77080074, 2557.98866551,
#        3297.01231265, 5315.02250375, 2776.52846677, 3126.37250525,
#        2415.39565526, 6373.055153  , 2881.76171869, 2564.51401248,
#        3230.62264892, 2762.36676189, 5327.25338033, 4011.00747562,
#        5390.67904791, 3543.81869589, 2357.81396296, 7544.1512501 ,
#        6297.99041196, 3809.50430628, 3888.59497775, 5300.6727374 ,
#        8816.80224738, 7619.84973463, 2926.88368563, 4282.26330636,
#        2896.03507575, 4103.50493754, 3179.79466475, 2468.44659663,
#        4761.07348815, 5848.80453224, 5485.2624881 , 1844.92116696,
#        9501.09735678, 2179.96282318, 5258.23835791, 2617.70469041,
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score
training_data_prediction=reg.predict(x_train)

# %%
r2_train=metrics.r2_score(y_train,training_data_prediction)

# %%
r2_train
# Out:
# 0.39959368702324183

# %%
test_data_prediction=reg.predict(x_test)
r2_test=metrics.r2_score(y_test,test_data_prediction)
r2_test
# Out:
# 0.36164702426392425

# %%
mse = mean_squared_error(y_train, training_data_prediction)
mse
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 mse = mean_absolute_error(y_train, training_data_prediction)
#       2 mse
#
# NameError: name 'mean_absolute_error' is not defined

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 2326.2052003517233

# %%
y_test
# Out:
# 1325    2954
# 2216    4347
# 1264    4917
# 1314    2840
# 86      1898
#         ...
# 2378    4195
# 2028    5430
# 2462    1921
# 1711    4232
# 1262    1845
# Name: ElapsedTime(second), Length: 453, dtype: int64

# %%
mae=metrics.mean_absolute_error(y_test,test_data_prediction)

# %%
mae
# Out:
# 1753.8435912130785

# %%
df=pd.read_csv('test.csv', encoding='latin-1')

# %%
df.isnull().sum()
# Out:
# ID                       0
# DiagnosticICD10Code     95
# SurgeryGroup             0
# AnesthesiaType          95
# SurgeryName            149
# Age                      0
# Sex                      0
# Service                  0
# DoctorID                 0
# AnaesthetistID           0
# dtype: int64

# %%
df= df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# ID                     0
# DiagnosticICD10Code    0
# SurgeryGroup           0
# AnesthesiaType         0
# SurgeryName            0
# Age                    0
# Sex                    0
# Service                0
# DoctorID               0
# AnaesthetistID         0
# dtype: int64

# %%
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Certain infectious and parasitic diseases' if "'A" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Certain infectious and parasitic diseases' if "'B" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Neoplasms' if "'C" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Neoplasms' if "'D0"in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Neoplasms' if "'D1"in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Neoplasms' if "'D2"in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Neoplasms' if "'D3"in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Neoplasms' if "'D4"in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism' if "'D5" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism' if "'D6" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism' if "'D7" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism' if "'D8" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism' if "'D9" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Endocrine, nutritional and metabolic diseases' if "'E" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Mental, Behavioral and Neurodevelopmental disorders' if "'F" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the nervous system' if "'G" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the eye and adnexa' if "'H0" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the eye and adnexa' if "'H1" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the eye and adnexa' if "'H2" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the eye and adnexa' if "'H3" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the eye and adnexa' if "'H4" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the eye and adnexa' if "'H5" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the ear and mastoid process' if "'H6" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the ear and mastoid process' if "'H7" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the ear and mastoid process' if "'H8" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the ear and mastoid process' if "'H9" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the circulatory systems' if "'I" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the respiratory system' if "'J" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the digestive system' if "'K" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the skin and subcutaneous tissue' if "'L" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the musculoskeletal system and connective tissue' if "'M" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Diseases of the genitourinary system' if "'N" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Pregnancy, childbirth and the puerperium' if "'O" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Certain conditions originating in the perinatal period' if "'P" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Congenital malformations, deformations and chromosomal abnormalities' if "'Q" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified' if "'R" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Injury, poisoning and certain other consequences of external causes' if "'S" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Injury, poisoning and certain other consequences of external causes' if "'T" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Codes for special purposes' if "'U" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'External causes of morbidity' if "'V" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'External causes of morbidity' if "'W" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'External causes of morbidity' if "'Y" in x else x)
df['DiagnosticICD10Code'] = df['DiagnosticICD10Code'].apply(lambda x: 'Factors influencing health status and contact with health services' if "'Z" in x else x)

# %%
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "4000" if "A1" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "2500" if "A2" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "1250" if "A3" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "750" if "B" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "400" if "C" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "200" if "D" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "100" if "E" in x else x)
df['SurgeryGroup'] = df['SurgeryGroup'].apply(lambda x: "0" if "{0}" in x else x)

# %%
df.head()
# Out:
#      ID                                DiagnosticICD10Code SurgeryGroup  \
# 1  2091       Diseases of the skin and subcutaneous tissue          400
# 2   585  Diseases of the musculoskeletal system and con...         1250
# 3  1455  Injury, poisoning and certain other consequenc...          750
# 4  1801                Diseases of the circulatory systems          100
# 5  1418                   Diseases of the digestive system          400
#
#     AnesthesiaType                                        SurgeryName  Age  \
# 1  Spinal Anestezi                                     Pilonidal kist   41
# 2   Genel Anestezi       Servikal disk bozukluklar?, radikülopati ile   59
# 3   Genel Anestezi                              Humerus üst uç k?r???   54
# 4    Sedo Analjezi  Ülser veya enflamasyon olmadan alt ekstremiten...   50
# 5  Spinal Anestezi  Bilateral inguinal herni, obstrüksiyonsuz veya...   31
#
#       Sex                Service  DoctorID  AnaesthetistID
# ...

# %%
df["SurgeryGroup"]=df["SurgeryGroup"].astype("int64")

# %%
df["DiagnosticICD10Code"]=encoder.fit_transform(df["DiagnosticICD10Code"])
df["AnesthesiaType"]=encoder.fit_transform(df["AnesthesiaType"])
df["Sex"]=encoder.fit_transform(df["Sex"])
df["Service"]=encoder.fit_transform(df["Service"])
df["DoctorID"]=encoder.fit_transform(df["DoctorID"])
df["AnaesthetistID"]=encoder.fit_transform(df["AnaesthetistID"])

# %%
df.head()
# Out:
#      ID  DiagnosticICD10Code  SurgeryGroup  AnesthesiaType  \
# 1  2091                   11           400               6
# 2   585                    8          1250               2
# 3  1455                   15           750               2
# 4  1801                    3           100               5
# 5  1418                    4           400               6
#
#                                          SurgeryName  Age  Sex  Service  \
# 1                                     Pilonidal kist   41    1        0
# 2       Servikal disk bozukluklar?, radikülopati ile   59    0        7
# 3                              Humerus üst uç k?r???   54    0        7
# 4  Ülser veya enflamasyon olmadan alt ekstremiten...   50    1        5
# 5  Bilateral inguinal herni, obstrüksiyonsuz veya...   31    1        0
#
#    DoctorID  AnaesthetistID
# 1        28               5
# 2        33              12
# 3        16              12
# 4        36              11
# 5        37               0

# %%
test_df=df.drop(columns=["ID","SurgeryName"], axis=1)

# %%
test_df
# Out:
#       DiagnosticICD10Code  SurgeryGroup  AnesthesiaType  Age  Sex  Service  \
# 1                      11           400               6   41    1        0
# 2                       8          1250               2   59    0        7
# 3                      15           750               2   54    0        7
# 4                       3           100               5   50    1        5
# 5                       4           400               6   31    1        0
# ...                   ...           ...             ...  ...  ...      ...
# 1110                    4           400               2   66    0        0
# 1111                    8           400               2   61    0        7
# 1112                    7           200               5    4    1        9
# 1113                    4           750               6   62    1        0
# 1114                    4           750               2   58    1        0
#
#       DoctorID  AnaesthetistID
# 1           28               5
# ...

# %%
reg.predict(test_df)
# Out:
# array([ 3328.36948568,  9679.43743225,  7658.44067896,  2490.79546207,
#         2573.30532816,  4820.35797317,  3051.12040564,  2770.58218376,
#         3211.35794898,  5373.57687547,  7511.24806083,  5070.79490253,
#         5899.91683933,  5997.53662055,  3124.64552254,  5853.56466816,
#         5645.42549362,  8354.17319391,  6671.22673591,  5022.96111786,
#         4878.24358736,  4981.54754026,  5215.94636275,  2869.28554602,
#         6813.55935237,  5169.02701595,  4329.99303859,  3570.96895258,
#         4861.01260254,  4423.22814066,  4583.91593347,  2125.31412468,
#         5840.55537347,  5727.05008043,  9430.21620588,  3351.77715479,
#         2492.82286416,  4924.59551803,  2116.3702061 ,  4754.91890522,
#         3246.75872534,  2186.193487  ,  5557.65974485,  2858.42133216,
#         6037.53744159,  6429.96908586,  6106.09672   ,  5820.89109908,
#         2010.08528971,  5864.79691747,  4999.05887679,  8571.86790069,
# ...
